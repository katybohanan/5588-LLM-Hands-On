# %% [markdown]
# <a href="https://colab.research.google.com/github/katybohanan/5588-LLM-Hands-On/blob/main/5588_LLM_Hands_On.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install necessary libraries
# !pip install transformers

# %%
from transformers import pipeline
summarizer = pipeline("summarization")
text = "Large language models are transforming natural language processing..."
summary = summarizer(text, max_length=50, min_length=25,
do_sample=False)
print(summary)
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# Your max_length is set to 50, but your input_length is only 11. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=5)
# [{'summary_text': ' Large language models are transforming natural language processing . Language models are turning natural language models into models for language models . The models are being used to develop new ways of visual language models to make sense of complex language systems .'}]

# %%
from google.colab import files
uploaded = files.upload() # Upload your file
for filename in uploaded.keys():
    print(f"Processing file: {filename}")
    with open(filename, 'r') as file:
      text = file.read()
      summary = summarizer(text, max_length=100, min_length=25, do_sample=False)
      print(f"Summary: {summary}")
# Out:
#      <input type="file" id="files-fc80c1d2-ed4f-431c-b257-5ae0d191a502" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fc80c1d2-ed4f-431c-b257-5ae0d191a502">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# #Sentiment Analysis

# %%
classifier = pipeline("sentiment-analysis")
result = classifier("I love learning about AI!")
print(result)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Device set to use cpu
# [{'label': 'POSITIVE', 'score': 0.99968421459198}]

# %%
classifier = pipeline("sentiment-analysis")
result = classifier("The store was a mess.")
print(result)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# [{'label': 'NEGATIVE', 'score': 0.9998026490211487}]

# %% [markdown]
# #Text Generation

# %%
generator = pipeline(model="openai-community/gpt2")
result = generator("The secret to making the best cherry pie is ", do_sample=False)
print(result)
# Out:
# Device set to use cpu
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "The secret to making the best cherry pie is \xa0to make it as good as possible. \xa0I've been making cherry pie for years and I've never had a problem with it. \xa0I've tried to make it as good as"}]

# %%
text2text_generator = pipeline("text2text-generation")
text2text_generator("Can you convert this text to French language: Hello, How are you")
# Out:
# No model was supplied, defaulted to google-t5/t5-base and revision a9723ea (https://huggingface.co/google-t5/t5-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# [{'generated_text': 'Bonjour, Comment êtes-vous?'}]
